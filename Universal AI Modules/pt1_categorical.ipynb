# %%
#!pip install seaborn pandas matplotlib

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Basic Plots (Bar Chart, Pie Chart, Line Chart)
#
# Here's a quick overview of **basic plots** types used in data visualization,
# with common uses and distinguishing features.

# %% [markdown]
# # Exploring Categorical Data - BMI Data Analysis with Visualizations
#
# This notebook demonstrates how to analyze and visualize BMI data using Python. It includes examples of:
#
# *   Creating and displaying DataFrames
# *   Calculating percentages
# *   Creating bar charts (grouped and stacked)
# *   Creating a pie chart.

# %%
# Create a DataFrame with the BMI ranges and categories
bmi_data = {
    "BMI range": ["< 18.5", "18.5-24.9", "25.0-29.9", "30.0 and above"],
    "Category": ["Underweight", "Normal weight", "Overweight", "Obese"]
}

bmi_df = pd.DataFrame(bmi_data)

# %%
bmi_df
# Out:
#         BMI range       Category
# 0          < 18.5    Underweight
# 1       18.5-24.9  Normal weight
# 2       25.0-29.9     Overweight
# 3  30.0 and above          Obese

# %%
bmi_df["Sample Count"] = [25, 500, 175, 50] # Hypothetical Values
total_count = bmi_df["Sample Count"].sum()

#Calculate percentage
bmi_df["Percentage"] = (bmi_df["Sample Count"] / total_count) * 100
bmi_df["Percentage"] = bmi_df["Percentage"].round(1)

# %%
bmi_df
# Out:
#         BMI range       Category  Sample Count  Percentage
# 0          < 18.5    Underweight            25         3.3
# 1       18.5-24.9  Normal weight           500        66.7
# 2       25.0-29.9     Overweight           175        23.3
# 3  30.0 and above          Obese            50         6.7

# %%
sns.set_context("talk")

# %%
# Create a bar chart of sample counts by BMI category
with plt.style.context ('fivethirtyeight'):

  plt.figure(figsize=(10, 4.5))
  plt.bar(bmi_df["Category"], bmi_df["Sample Count"])
  plt.xlabel("BMI Category")
  plt.ylabel("Count")
  plt.title("BMI Categories for students\nClass,2025")
  # plt.xticks(rotation=45)
  plt.tight_layout()
  plt.grid(axis='x')


  plt.show()

# %%
# Create a bar chart of sample counts by BMI category
with plt.style.context ('fivethirtyeight'):

  plt.figure(figsize=(10, 4.5))
  plt.barh(bmi_df["Category"], bmi_df["Sample Count"])
  plt.ylabel("BMI Category")
  plt.xlabel("Count")
  plt.title("BMI Categories for students\nClass,2025")
  # plt.xticks(rotation=45)
  plt.tight_layout()
  plt.grid(axis='y')


  plt.show()

# %%
# Create a bar chart of sample counts by BMI category
with plt.style.context ('fivethirtyeight'):

  plt.figure(figsize=(10, 4.5))
  plt.bar(bmi_df["Category"], bmi_df["Percentage"])
  plt.xlabel("BMI Category")
  plt.ylabel("Percentage(%)")
  plt.title("BMI Categories for students\nClass,2025")
  # plt.xticks(rotation=45)
  plt.tight_layout()
  plt.grid(axis='x')


  plt.show()

# %%
#BMI data across three years
data = {
    "BMI range": [
        "Underweight",
        "Normal",
        "Overweight",
        "Obese",
        "Total"
    ],

    "2015 Count": [50, 400, 100, 10, 560],
    "2015 %" : ["8.9%", "71.4%", "17.9%", "1.8%", "100.0%"],
    "2020 Count": [45, 450, 130, 40, 665],
    "2020 %":["6.8%", "67.7%", "19.5%", "6.0%", "100.0%"],
    "2025 Count": [25, 500, 175, 50, 750],
    "2025 %": ["3.3%", "66.7%", "23.3%", "6.7%", "100.0%"]

}

bmi_df = pd.DataFrame(data)

bmi_df
# Out:
#      BMI range  2015 Count  2015 %  2020 Count  2020 %  2025 Count  2025 %
# 0  Underweight          50    8.9%          45    6.8%          25    3.3%
# 1       Normal         400   71.4%         450   67.7%         500   66.7%
# 2   Overweight         100   17.9%         130   19.5%         175   23.3%
# 3        Obese          10    1.8%          40    6.0%          50    6.7%
# 4        Total         560  100.0%         665  100.0%         750  100.0%

# %%
# Plot group chart

with plt.style.context('fivethirtyeight'):

  plot_df = bmi_df.iloc[:4].copy()
  plot_df["2025 %"] = plot_df["2025 %"].str.rstrip('%').astype(float)
  plot_df["2020 %"] = plot_df ["2020 %"].str.rstrip('%').astype(float)
  plot_df["2015 %"] = plot_df["2015 %"].str.rstrip('%').astype(float)

  x = np.arange(len(plot_df["BMI range"]))
  width = 0.25


  # plt.figure (figsize=(10,6))

  plt.figure(figsize=(10, 4.5))
  plt.bar(x - width, plot_df["2015 %"], width, label = "2015")
  plt.bar(x, plot_df["2020 %"], width, label="2020")
  plt.bar(x + width, plot_df["2025 %"], width, label ="2025")

  plt.xlabel("BMI Category")
  plt.ylabel("Percentage (%)")
  plt.title("BMI Distribution in Three Entering Classes")
  plt.xticks(x, plot_df["BMI range"], rotation=45)
  plt.legend()
  plt.tight_layout()
  plt.grid(axis='x')
  plt.show()

# %%
with plt.style.context ("fivethirtyeight"):
  years = ['2015', '2020', '2025']
  underweight = plot_df ["2015 %"].values[0], plot_df['2020 %'].values[0],plot_df["2025 %"].values[0]
  normal = plot_df["2015 %"].values[1], plot_df["2020 %"].values[1], plot_df["2025 %"].values[1]
  overweight = plot_df["2015 %"].values[2], plot_df["2020 %"].values[2], plot_df["2025 %"].values[2]
  obese = plot_df ["2015 %"].values[3], plot_df["2020 %"].values[3], plot_df["2025 %"].values[3]

  x = np.arange(len(years))

  plt.figure(figsize = (10, 4.5))
  plt.bar(x, underweight, label = 'underweight')
  plt.bar(x, normal, bottom = underweight, label = 'Normal')
  plt.bar(x, overweight, bottom=np.array(underweight) + np.array(normal), label = 'Overweight')
  plt.bar(x, obese,
          bottom = np.array(underweight) + np.array(normal) + np.array(overweight),
          label = 'Obese')

  plt.xticks (x, years)
  plt.xlabel ("Year")
  plt.ylabel ("Percentage (%)")
  plt.title ("BMI Category Distribution (Stacked) by Year")
  plt.legend (loc = 'upper left', bbox_to_anchor = (1, 1))
  plt.tight_layout()
  plt.grid(axis ='x')
  plt.show()

# %%
labels = plot_df ["BMI range"]
sizes = plot_df ["2015 %"]

plt.figure(figsize = (10, 4.5))
wedges, texts, autotexts = plt.pie(
    sizes,
    #labels = labels,
    autopct = '%1.0f%%',
    #labeldistance = 1.3.  #Pushes labels outward
    pctdistance = 1.3,
    startangle= 180)

plt.title("BMI Category Distribution for Students\nClass, 2015")

plt.legend(wedges, labels, title = "BMI Categories", loc = "center left", bbox_to_anchor=(1, 0.5))

plt.axis ('equal')
plt.show()

# %% [markdown]
# # **Exploring Time Series Data**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-247bfccd-9363-4c87-9e62-b25e7a343500" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-247bfccd-9363-4c87-9e62-b25e7a343500">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
unmp = pd.read_csv ('SeriesReport-20250123143139_bcaef0.csv')
df_melted = unmp.melt(id_vars=["Year"], var_name="Month", value_name="Value")
df_melted["Date"] = pd.to_datetime(df_melted["Year"].astype(str) + "-" + df_melted["Month"])
df_melted = df_melted.sort_values("Date")
# Out:
# /tmp/ipython-input-33-4250609741.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_melted["Date"] = pd.to_datetime(df_melted["Year"].astype(str) + "-" + df_melted["Month"])

# %%
unmp.head()
# Out:
#    Year  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# 0  1950  6.5  6.4  6.3  5.8  5.5  5.4  5.0  4.5  4.4  4.2  4.2  4.3
# 1  1951  3.7  3.4  3.4  3.1  3.0  3.2  3.1  3.1  3.3  3.5  3.5  3.1
# 2  1952  3.2  3.1  2.9  2.9  3.0  3.0  3.2  3.4  3.1  3.0  2.8  2.7
# 3  1953  2.9  2.6  2.6  2.7  2.5  2.5  2.6  2.7  2.9  3.1  3.5  4.5
# 4  1954  4.9  5.2  5.7  5.9  5.9  5.6  5.8  6.0  6.1  5.7  5.3  5.0

# %%
figsize = (10, 4)
title = "Unemployment Rate in the United States (1950-2024)"
value = "Rate (%)"
date = "Year"

# %%
with plt.style.context('fivethirtyeight'):
  # Plot the timeline
  plt.figure(figsize = figsize)
  plt.plot (df_melted["Date"], df_melted["Value"]) #, marker = 'o')
  plt.title(title)
  plt.xlabel (date)
  plt.ylabel (value)
  plt.ylim(-1, 16)
  plt.grid(True)
  plt.xlim(df_melted["Date"].min(), df_melted["Date"].max())
  plt.tight_layout()
  plt.show()

# %%
with plt.style.context("fivethirtyeight"):
  plt.figure(figsize = figsize)
  plt.bar(df_melted["Date"], df_melted["Value"], width = 30, align = 'center')
  plt.title(title)
  plt.xlabel(date)
  plt.ylabel(value)
  #plt.xticks(rotation = 45)
  plt.ylim(-1, 16)
  plt.xlim(df_melted["Date"].min(), df_melted["Date"].max())
  #plt.grid(axis ='xy')
  plt.tight_layout()
  plt.show()

# %%
with plt.style.context('tableau-colorblind10'):

  temp = df_melted[df_melted["Month"] == "Jan"]

  plt.figure(figsize=(10,4))
  plt.bar(temp["Date"], temp["Value"], width = 250, align = 'center')
  plt.title ("Unemployment rate")
  plt.xlabel("Date")
  plt.ylabel("Unemployment Rate (%)")
  plt.xticks(rotation = 45)
  plt.ylim(0,16)
  plt.xlim(df_melted["Date"].min(), df_melted["Date"].max())
  plt.grid(axis ='y')
  plt.tight_layout()
  plt.show()

# %%
with plt.style.context('fivethirtyeight'):
  plt.figure(figsize=(10,4))
  plt.plot(temp["Date"], temp["Value"], "o", markersize=4, label ="value")
  plt.title(title)
  plt.xlabel(date)
  plt.ylabel(value)
  # plt.xticks(rotation = 45)
  plt.ylim(-1,16)
  #plt.grid(axis = 'x')
  plt.xlim(df_melted["Date"].min(), df_melted["Date"].max())
  plt.legend()
  plt.tight_layout()
  plt.show()

# %%
with plt.style.context('tableau-colorblind10'):
  plt.figure(figsize=(10,4))
  plt.plot(df_melted["Date"], df_melted["Value"], "o", markersize=3, label ="Value")
  plt.title("Unemployment rate")
  plt.xlabel("Date")
  plt.ylabel("Unemployemnt Rate (%)")
  plt.xticks(rotation = 45)
  plt.ylim(-1,16)
  plt.grid(axis = 'y')
  plt.xlim(df_melted["Date"].min(), df_melted["Date"].max())
  plt.legend()
  plt.tight_layout()
  plt.show()

# %%
# Highlight the background for 2005 - 2006

with plt.style.context('fivethirtyeight'):
  fig, ax = plt.subplots(figsize=(10, 4))
  plt.plot(df_melted["Date"], df_melted["Value"], markersize=3, label = "Value")
  plt.axvspan(pd.to_datetime("2020-01-30"), pd.to_datetime("2020-05-1"), color ='yellow', alpha = 0.2)

  plt.axvspan(pd.to_datetime("1953-07-01"), pd.to_datetime("1954-05-01"), color ='yellow', alpha = 0.2)
  plt.axvspan(pd.to_datetime("1957-08-01"), pd.to_datetime("1958-04-01"), color ='yellow', alpha = 0.2)
  plt.axvspan(pd.to_datetime("1960-04-01"), pd.to_datetime("1961-02-01"), color ='yellow', alpha = 0.2)
  plt.axvspan(pd.to_datetime("1969-12-01"), pd.to_datetime("1961-02-01"), color ='yellow', alpha = 0.2)
  plt.axvspan(pd.to_datetime("1973-11-01"), pd.to_datetime("1975-03-01"), color ='yellow', alpha = 0.2)
  plt.axvspan(pd.to_datetime("1980-01-01"), pd.to_datetime("1980-07-01"), color ='yellow', alpha = 0.2)
  plt.axvspan(pd.to_datetime("2007-12-01"), pd.to_datetime("2009-07-01"), color ='yellow', alpha = 0.2)

  #ax.annotate(
  #   'Recession',
  #    xy = (pd.to_datetime("1960-04-01"), 12),  #Point to shaded area
  #    xytext = (pd.to_datetime("1964-06-01"), 12), # Position of text
  #    arrowprops = dict(facecolor='black', color ='black;, arrowstyle ='->', lw=1),
  #    fontsize =16,
  #    color = 'black'
  #)

  #plt.title ("Rising Unemployment During periods of Economic Recession", fontsize = 19)
  plt.title(title)
  plt.xlabel(date)
  plt.ylabel(value)

  #plt.xticks(rotation=45)
  plt.xlim(df_melted["Date"].min(), df_melted["Date"].max())

  plt.ylim(-1, 16)
  plt.grid(axis = 'x')
  plt.tight_layout()

  plt.show()

# %%
t = df_melted.groupby("Year").agg({"Value": "mean"}).reset_index()
t.head()
# Out:
#    Year     Value
# 0  1950  5.208333
# 1  1951  3.283333
# 2  1952  3.025000
# 3  1953  2.925000
# 4  1954  5.591667

# %%
with plt.style.context('fivethirtyeight'):
  plt.figure(figsize = (10, 4))
  # sns.barplot(data=t, x="Year", y="Value")
  plt.bar(t["Year"], t["Value"]) #, width=250, align= 'center')
  plt.title(title)
  plt.xlabel(date)
  plt.ylabel(value)
  plt.ylim(-1,16)
  plt.xlim(df_melted["Year"].min()-1, df_melted["Year"].max()+1)
  # plt.grid(True)
  plt.tight_layout()
  plt.show()

# %%
with plt.style.context('tableau-colorblind10'):
  plt.figure(figsize=(10, 4))
  plt.plot(temp["Date"], temp["Value"], markersize = 3,
           marker = 'o')
  plt.title("Monthly Data Timeline")
  plt.xlabel("Date")
  plt.ylabel("Value")
  plt.ylim(0, 16)
  plt.xlim(df_melted["Date"].min(), df_melted["Date"].max())
  plt.grid(True)
  plt.tight_layout()
  plt.show()

# %%
import numpy as np
import statsmodels.api as sm
from statsmodels.nonparametric.smoothers_lowess import lowess

# Apply LOESS smoothing
loess_smoothed = lowess (df_melted["Value"], df_melted["Date"].astype(np.int64), frac=0.2)

with plt.style.context ("fivethirtyeight"):
  #Plot the original data and LOESS smoothed line
  plt.figure(figsize = figsize)
  plt.plot(temp["Date"], temp["Value"], 'o', markersize=3, label= "Rate (%)")
  #plt.plot(temp["Date"], temp["Value"], markersize=3, marker='o', label="value")
  plt.plot(pd.to_datetime(loess_smoothed[:, 0]), loess_smoothed[:, 1], color ='red', label = "LOWESS Smothed")
  #plt.title("Monthly Data Timeline with LOESS smoothing")
  #plt.xlabel("Date")
  #plt.ylabel("Value")
  plt.title(title)
  plt.ylabel(value)
  plt.ylim(-1, 16)
  plt.xlim(df_melted["Date"].min(), df_melted["Date"].max())
  plt.legend()
  plt.grid(True)
  plt.tight_layout()
  plt.show()

# %%
annual_avg = df_melted.groupby(["Year"])["Value"].mean()
annual_change = annual_avg.diff().reset_index() #Calculate year-over-year change

with plt.style.context('fivethirtyeight'):
  # Plot the annual change
  plt.figure(figsize=figsize)
  plt.bar(annual_change["Year"], annual_change["Value"]) #, color = 'skyblue', edgecolor='black')
  plt.title("Annual Change in Unemployment Rate in the US (1950-2024)")
  plt.xlabel("Year")
  # plt.xlim(df_melted["Date"].min(), df_melted["Date"].max())
  plt.ylabel("Change in Rate(%)")
  #plt.grid(axis='y', linestyle = '--', alpha=0.7)
  #plt.title(title)
  plt.xlabel(date)
  plt.grid(axis='x')


  #plt.ylim(-1,16)
  plt.xlim(annual_change["Year"].min(), annual_change["Year"].max()+1)
  plt.tight_layout()
  plt.show()
